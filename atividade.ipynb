# %% [markdown]
# Atividade de PA, 1C - Lívia de Oliveira Duarte

# %%
# Questão 1 - programa de classificação de idade

nome = str (input("Por favor, digite seu nome: "))
idade = int (input("Agora digite sua idade: "))

if idade <= 17:

 print (f"Olá, {nome}! Você é menor de idade.")


elif idade >= 18 and idade <= 59:
 
 print (f"Olá, {nome}! Você é adulto(a).")
 
elif idade >= 60:
 
 print (f"Olá, {nome}! Você é idoso(a).")
# Out:
# Olá, Oliver! Você é adulto(a).

# %%
# Questão 2 - programa de cálculo de desconto

item1 = int (input ("Olá! Por favor digite o preço do primeiro item: "))
item2 = int (input ("Ok, agora adicione o preço do segundo item: "))
item3 = int (input ("Agora o preço do terceiro item: "))
item4 = int (input ("E por último, o preço do quarto item: "))
print = str ("Obrigado!")

compra = item1 + item2 + item3 + item4

if compra <= 100:
  print (f"Sua compra deu {compra}, não temos um desconto para você, desculpe!")

elif compra > 100 and idade <= 500:

    desconto = compra * 0.9
    print (f"Sua compra deu {compra}, porém você recebeu um desconto de 10%! Logo, agora o valor a se pagar é {desconto}.")

else:

    desconto = compra * 0.8
    print (f"Sua compra deu {compra}, porém você recebeu um desconto de 20%! Logo, agora o valor a se pagar é {desconto}.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 17
#      14 elif compra > 100 and idade <= 500:
#      16     desconto = compra * 0.9
# ---> 17     print (f"Sua compra deu {compra}, porém você recebeu um desconto de 10%! Logo, agora o valor a se pagar é {desconto}.")
#      19 else:
#      21     desconto = compra * 0.8
#
# TypeError: 'str' object is not callable

# %%
# Questão 3 - programa de  verificação de triângulo

lado1 = (input("Por favor, digite o valor do primeiro lado do triângulo: "))
lado2 = (input("Agora digite o valor do segundo lado do triângulo: "))
lado3 = (input("E por último, digite o valor do terceiro lado do triângulo: "))


if lado1 + lado2 > lado3 or lado1 + lado3 > lado2 or lado2 + lado3 > lado1:

 print ("Um triângulo com estas medidas é possível!")

else:
 
  print ("Um triângulo com essas medidas não é possível.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Questão 3 - programa de  verificação de triângulo
# ----> 3 lado1 = (input("Por favor, digite o valor do primeiro lado do triângulo: "))
#       4 lado2 = (input("Agora digite o valor do segundo lado do triângulo: "))
#       5 lado3 = (input("E por último, digite o valor do terceiro lado do triângulo: "))
#
# File c:\Users\lab1-aluno\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# ...

# %%
# Questão 4 - programa de  sistema de energia
