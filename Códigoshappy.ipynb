# %% [markdown]
# <a href="https://colab.research.google.com/github/Livia-deOliveira/PA-1C-grupo-A/blob/main/C%C3%B3digoshappy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular a área do retângulo

# %% [markdown]
# # Fazer um cadastro de usuário simples.
# # Entrada: nome e idade
# # Processamento: armazenar os dados
# # Saída: mensagem de boas-vindas

# %%
# Entrada

comprimento= float (input("digite o valor do comprimento: "))
largura = float (input("digite o valor da altura: "))

# Processamento

área = comprimento * largura

# Saída

print ("    --------ÁREA DO RETÂNGULO--------")
print ("")
print (f"a área total do retângulo é igual a: {área}")
print ("")
print ("------------------------------------------------")
# Out:
# digite o valor do comprimento: 22
# digite o valor da altura: 28
#     --------ÁREA DO RETÂNGULO--------
#
# a área total do retângulo é igual a: 616.0
#
# ------------------------------------------------

# %%
# Entrada

nome = str (input ("digite o seu nome: "))
idade = str (input("digite sua idade: "))

# Saída

print ("-----------------------------------")
print ("")
print (f"Olá, {nome}. Seja bem-vindo(a)!")
print ("")
print (f"Você tem {idade} anos, certo?")
print ("")
print ("-----------------------------------")
# Out:
# digite o seu nome: Spooky Scary
# digite sua idade: Skeleton
# -----------------------------------
#
# Olá, Spooky Scary. Seja bem-vindo(a)!
#
# Você tem Skeleton anos, certo?
#
# -----------------------------------

# %% [markdown]
# Fazer um programa que converte a temperatura de celsius para fahrenheit.
#
# # Entrada: graus celsius
#
# # Processamento: converter a temperatura para Fahrenheit.
#
# # Saída: Mostrar a temperatura em Fahrenheit.
#
# F = (C * 9/5) + 32

# %%
# Entrada

Celsius = int (input ("Digite a Temperatura em graus Celsius: "))

# Processamento

F = int (Celsius * 9/5) + 32

# Saída

print ("")
print ("------------------------------------------")
print ("")
print (f" A temperatura em graus Fahrenheit é: {F}")
print ("")
print ("------------------------------------------")
# Out:
# Digite a Temperatura em graus Celsius: 25
#
# ------------------------------------------
#
#  A temperatura em graus Fahrenheit é: 77
#
# ------------------------------------------

# %% [markdown]
# # Operadores Aritiméticos
#
# # Soma de dois números

# %%
from ast import Subscript
from os import supports_bytes_environ
# Entrada

("")
print ("------------------------------------------")
print ("")
a = int (input ("Digite o primeiro número: "))
b = int (input ("Digite o segundo número: "))
print ("")
print ("------------------------------------------")

# Processamento

soma = a + b
subtração = a - b
multiplicação = a * b
divisão = a / b
divisão_int = a // b
resto = a % b

# Saída

print ("")
print ("------------------SOMA--------------------")
print ("")
print ("------------------------------------------")
print ("")
print (f"  A soma de {a} mais {b} é igual a: {soma}")
print ("")
print ("------------------------------------------")

print ("")
print ("-----------------SUBTRAÇÃO-----------------")
print ("")
print ("------------------------------------------")
print ("")
print (f"  A subtração de {a} menos {b} é igual a: {subtração}")
print ("")
print ("------------------------------------------")

print ("")
print ("---------------MULTIPLICAÇÃO--------------")
print ("")
print ("------------------------------------------")
print ("")
print (f"  A multiplicação de {a} vezes {b} é igual a: {multiplicação}")
print ("")
print ("------------------------------------------")

print ("")
print ("------------------DIVISÃO----------------")
print ("")
print ("------------------------------------------")
print ("")
print (f"  A divisão de {a} dividido {b} é igual a: {divisão}")
print ("")
print ("------------------------------------------")

print ("")
print ("--------------DIVISÃO INTEIRA--------------")
print ("")
print ("------------------------------------------")
print ("")
print (f"  A divisão de {a} dividido {b} é igual a: {divisão_int}")
print ("")
print ("------------------------------------------")

print ("")
print ("------------------RESTO--------------------")
print ("")
print ("------------------------------------------")
print ("")
print (f"  A divisão de {a} dividido {b} é igual a: {resto}")
print ("")
print ("------------------------------------------")
# Out:
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_979/1800730707.py in <cell line: 0>()
#       6 print ("------------------------------------------")
#       7 print ("")
# ----> 8 a = int (input ("Digite o primeiro número: "))
#       9 b = int (input ("Digite o segundo número: "))
#      10 print ("")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Entrada

print ("------------------------------------------")
print ("")
Num1 = int (input ("Digite o primeiro número: "))
Num2 = int (input ("Digite o segundo número: "))
print ("")

#Processamento

igual = Num1 == Num2
diferente = Num1 != Num2
maior = Num1 > Num2
menor = Num1 < Num2
menor_igual = Num1 <= Num2
maior_igual = Num1 >= Num2


# Saída

print ("------------------------------------------")
print ("")
print ("-----------------RESULTADOS----------------")
print ("")
print(f"{Num1} é igual a {Num2}?: {igual}")
print ("")
print(f"{Num1} é diferente de {Num2}?: {diferente}")
print ("")
print(f"{Num1} é maior que {Num2}?: {maior}")
print ("")
print(f"{Num1} é menor que {Num2}?: {menor}")
print ("")
print(f"{Num1} é menor ou igual a {Num2}?: {menor_igual}")
print ("")
print(f"{Num1} é maior ou igual a {Num2}?: {maior_igual}")
print ("")
print ("------------------------------------------")
# Out:
# ------------------------------------------
#
# Digite o primeiro número: 70
# Digite o segundo número: 8
#
# ------------------------------------------
#
# -----------------RESULTADOS----------------
#
# 70 é igual a 8?: False
#
# 70 é diferente de 8?: True
#
# 70 é maior que 8?: True
#
# 70 é menor que 8?: False
#
# 70 é menor ou igual a 8?: False
#
# 70 é maior ou igual a 8?: True
#
# ------------------------------------------
